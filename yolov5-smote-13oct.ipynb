# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt

random.seed(108)

# %%
# !pwd

# %%
# %mkdir Road_Sign_Dataset
# %cd Road_Sign_Dataset
# !mkdir annotations
# !mkdir images

# %%
# %cd /kaggle/working/Road_Sign_Dataset
# !ls

# %%
#!rm -R Road_Sign_Dataset

# %%
# !cp -R /kaggle/input/tbx-11/TBX11K/annotations/xml/* /kaggle/working/Road_Sign_Dataset/annotations
# !cp -R /kaggle/input/tbx-11/TBX11K/imgs/tb/* /kaggle/working/Road_Sign_Dataset/images

# %%
# !pwd
# !ls

# %%
# Assuming you're in the data folder
# !cat /kaggle/working/Road_Sign_Dataset/annotations/tb0004.xml

# %%
root = ET.parse('/kaggle/working/Road_Sign_Dataset/annotations/tb0026.xml').getroot()
root

# %%
# Function to get the data from XML Annotation
def extract_info_from_xml(xml_file):
    root = ET.parse(xml_file).getroot()
    
    # Initialise the info dict 
    info_dict = {}
    info_dict['bboxes'] = []

    # Parse the XML Tree
    for elem in root:
        # Get the file name 
        if elem.tag == "filename":
            info_dict['filename'] = elem.text + '.xml'
            
        # Get the image size
        elif elem.tag == "size":
            image_size = []
            for subelem in elem:
                image_size.append(int(subelem.text))
            
            info_dict['image_size'] = tuple(image_size)
        
        # Get details of the bounding box 
        elif elem.tag == "object":
            bbox = {}
            for subelem in elem:
                if subelem.tag == "name":
                    bbox["class"] = subelem.text
                    
                elif subelem.tag == "bndbox":
                    for subsubelem in subelem:
                        bbox[subsubelem.tag] = int(subsubelem.text)            
            info_dict['bboxes'].append(bbox)
    
    return info_dict

# %%
import os
os.remove('/kaggle/working/Road_Sign_Dataset/annotations/tb1199.xml')
os.remove('/kaggle/working/Road_Sign_Dataset/images/tb1199.png')

# %%
print(extract_info_from_xml('/kaggle/working/Road_Sign_Dataset/annotations/tb0004.xml'))

# %%
{'bboxes': [{'class': 'trafficlight', 'xmin': 20, 'ymin': 109, 'xmax': 81, 'ymax': 237}, {'class': 'trafficlight', 'xmin': 116, 'ymin': 162, 'xmax': 163, 'ymax': 272}, {'class': 'trafficlight', 'xmin': 189, 'ymin': 189, 'xmax': 233, 'ymax': 295}], 'filename': 'road4.png', 'image_size': (267, 400, 3)}

# %%
# %cd /kaggle/working/Road_Sign_Dataset

# %%
#!rm -R /kaggle/working/Road_Sign_Dataset/labels

# %%
# Dictionary that maps class names to IDs
class_name_to_id_mapping = {"ActiveTuberculosis": 0,
                           "ObsoletePulmonaryTuberculosis": 1}
                            #,
                           #"speedlimit": 2,
                           #"crosswalk": 3}

# Convert the info dict to the required yolo format and write it to disk
def convert_to_yolov5(info_dict):
    print_buffer = []
    num_class_0 = 0
    num_class_1 = 0
    # For each bounding box
    for b in info_dict["bboxes"]:
        try:
            class_id = class_name_to_id_mapping[b["class"]]
        except KeyError:
            print("Invalid Class. Must be one from ", class_name_to_id_mapping.keys())
            
        if b["class"] == 'ActiveTuberculosis':
            num_class_0 = num_class_0 + 1
        else:
            num_class_1 = num_class_1 + 1
        
        # Transform the bbox co-ordinates as per the format required by YOLO v5
        b_center_x = (b["xmin"] + b["xmax"]) / 2 
        b_center_y = (b["ymin"] + b["ymax"]) / 2
        b_width    = (b["xmax"] - b["xmin"])
        b_height   = (b["ymax"] - b["ymin"])
        
        # Normalise the co-ordinates by the dimensions of the image
        image_c = 3
        image_w, image_h = info_dict["image_size"]  
        b_center_x /= image_w 
        b_center_y /= image_h 
        b_width    /= image_w 
        b_height   /= image_h 
        
        #Write the bbox details to the file 
        print_buffer.append("{} {:.3f} {:.3f} {:.3f} {:.3f}".format(class_id, b_center_x, b_center_y, b_width, b_height))
    
    #print(info_dict["filename"])
    # Name of the file which we have to save 
    save_file_name = os.path.join("annotations", info_dict["filename"].replace(".xml", ".txt"))
    
    
    # Save the annotation to disk
    print("\n".join(print_buffer), file= open(save_file_name, "w"))
    
    return num_class_0, num_class_1

# %%
#annotations = [os.path.join('annotations', x) for x in os.listdir('annotations') if x[-3:] == "xml"]
#annotations.sort()
#annotations

# %%
# Get the annotations
annotations = [os.path.join('annotations', x) for x in os.listdir('annotations') if x[-3:] == "xml"]
annotations.sort()
total_class_0 = 0 
total_class_1 = 0
# Convert and save the annotations
for ann in tqdm(annotations):
    info_dict = extract_info_from_xml(ann)
    #print(info_dict)
    num_class_0, num_class_1 = convert_to_yolov5(info_dict)
    total_class_0 = total_class_0 +num_class_0
    total_class_1 = total_class_1 +num_class_1
print( " No of Active boxes ", total_class_0)
print( " No of Obsolete boxes ", total_class_1)    
annotations = [os.path.join('annotations', x) for x in os.listdir('annotations') if x[-3:] == "txt"]

# %%
#{'bboxes': [{'class': 'ObsoletePulmonaryTuberculosis', 'xmin': 1446, 'ymin': 250, 'xmax': 2007, 'ymax': 1017}, {'class': 'ObsoletePulmonaryTuberculosis', 'xmin': 618, 'ymin': 391, 'xmax': 1177, 'ymax': 1013}], 'filename': 'tb0003', 'image_size': (2840, 2827)}

# %% [markdown]
# # Testing the annotations

# %%
#annotations

# %%
annotation_file = random.choice(annotations)

# %%
random.seed(0)

class_id_to_name_mapping = dict(zip(class_name_to_id_mapping.values(), class_name_to_id_mapping.keys()))

def plot_bounding_box(image, annotation_list):
    annotations = np.array(annotation_list)
    w, h = image.size
    
    plotted_image = ImageDraw.Draw(image)

    transformed_annotations = np.copy(annotations)
    transformed_annotations[:,[1,3]] = annotations[:,[1,3]] * w
    transformed_annotations[:,[2,4]] = annotations[:,[2,4]] * h 
    
    transformed_annotations[:,1] = transformed_annotations[:,1] - (transformed_annotations[:,3] / 2)
    transformed_annotations[:,2] = transformed_annotations[:,2] - (transformed_annotations[:,4] / 2)
    transformed_annotations[:,3] = transformed_annotations[:,1] + transformed_annotations[:,3]
    transformed_annotations[:,4] = transformed_annotations[:,2] + transformed_annotations[:,4]
    
    for ann in transformed_annotations:
        obj_cls, x0, y0, x1, y1 = ann
        plotted_image.rectangle(((x0,y0), (x1,y1)))
        
        plotted_image.text((x0, y0 - 10), class_id_to_name_mapping[(int(obj_cls))])
    
    plt.imshow(np.array(image))
    plt.show()

# Get any random annotation file 
annotation_file = random.choice(annotations)
with open(annotation_file, "r") as file:
    annotation_list = file.read().split("\n")[:-1]
    annotation_list = [x.split(" ") for x in annotation_list]
    annotation_list = [[float(y) for y in x ] for x in annotation_list]

#Get the corresponding image file
image_file = annotation_file.replace("annotations", "images").replace("txt", "png")
assert os.path.exists(image_file)

#Load the image
image = Image.open(image_file)

#Plot the Bounding Box
plot_bounding_box(image, annotation_list)

# %% [markdown]
# # Partition the dataset

# %%
annotations = [os.path.join('annotations', x) for x in os.listdir('annotations') if x[-3:] == "txt"]
#annotations

# %%
# Read images and annotations
images = [os.path.join('images', x) for x in os.listdir('images')]
annotations = [os.path.join('annotations', x) for x in os.listdir('annotations') if x[-3:] == "txt"]

images.sort()
annotations.sort()

# Split the dataset into train-valid-test splits 
train_images, val_images, train_annotations, val_annotations = train_test_split(images, annotations, test_size = 0.2, random_state = 1)
val_images, test_images, val_annotations, test_annotations = train_test_split(val_images, val_annotations, test_size = 0.5, random_state = 1)

# %% [markdown]
# # Started SMOTE

# %%
# Firstly, we must import some libs
import os
import numpy as np
import pandas as pd
import gc
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import json
import yaml
from shutil import copyfile
import matplotlib.pyplot as plt

import torch
from PIL import Image
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#View the distributio of categories in traning data
import json
from collections import Counter
json_file_path = '/kaggle/input/tbx-11/TBX11K/annotations/json/TBX11K_train_only_tb.json'


data = json.load(open(json_file_path, 'r'))
dict_cat = {}
for cat in data["categories"]:
    dict_cat[cat["id"]]= cat["name"]
    print(dict_cat[cat["id"]])
list_cat = []
for ann in data["annotations"]:
    list_cat.append(dict_cat[ann["category_id"]])
Counter(list_cat)
# Out:
# ActiveTuberculosis
# ObsoletePulmonaryTuberculosis
# PulmonaryTuberculosis
# Counter({'ActiveTuberculosis': 724, 'ObsoletePulmonaryTuberculosis': 178})

# %%
x_train_1.head()

# %%
# Split train dataset and test dataset according to annotation_id
X = pd.DataFrame(data["annotations"])
Y = pd.DataFrame(X["category_id"])
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.1,random_state=1,stratify = Y)
Counter(list(y_train["category_id"]))

print("X_TRAIN : ", x_train.count())
print("Y_TRAIN : ", y_train.count())
print(Counter(list_cat))
# Out:
# X_TRAIN :  id             811
# image_id       811
# category_id    811
# iscrowd        811
# area           811
# bbox           811
# width          811
# height         811
# dtype: int64
# Y_TRAIN :  category_id    811
# dtype: int64
# Counter({'ActiveTuberculosis': 724, 'ObsoletePulmonaryTuberculosis': 178})

# %%
#!cp -R /kaggle/input/tbx-11/TBX11K/annotations/json/TBX11K_train_only_tb.json /kaggle/working

# %%
def convert_coco_json_to_csv(filename):
    import pandas as pd
    import json
    
    # COCO2017/annotations/instances_val2017.json
    s = json.load(open(filename, 'r'))
    out_file = filename[:-5] + '.csv'
    out = open(out_file, 'w')
    out.write('id,x1,y1,x2,y2,class_name,boxwidth,boxheight, imagewidth, imageheight, file_name\n')

    dictclass = {}
    for cat in s['categories']:
        catKey = cat['id']
        catValue = cat['name']
        dictclass.update({catKey:catValue}) 
    
    
    sdict = {} 
    all_ids = []
    for im in s['images']:
        all_ids.append(im['id'])
        aKey = im['id']
        aValue = im['file_name']
        sdict.update({aKey:aValue})
        
        #imagefile = im['file_name']
        #classlabel = imagefile.rsplit('/', 1)[0]

    all_ids_ann = []
    for ann in s['annotations']:
        image_id = ann['image_id']
        all_ids_ann.append(image_id)
        x1 = ann['bbox'][0]
        x2 = ann['bbox'][0] + ann['bbox'][2]
        y1 = ann['bbox'][1]
        y2 = ann['bbox'][1] + ann['bbox'][3]
        
        boxwidth = ann['bbox'][2]
        boxheight = ann['bbox'][3]
        classid = ann['category_id']
        imagewidth = ann['width']
        imageheight = ann['height']
        
        # Find the index of the value in the list for id and filename
        values = list(sdict.keys())
        index = values.index(image_id)
        # Get the key from the dictionary using the index
        fname = list(sdict.values())[index]
          
    
        # GET Class name from class dictionary for each annotation
        classname = list(dictclass.keys())
        indexclass = values.index(classid)
        # Get the key from the dictionary using the index
        classname = list(dictclass.values())[indexclass] 
        
        out.write('{},{},{},{},{},{},{},{},{},{},{}\n'.format(image_id, x1, y1, x2, y2, classname,boxwidth,boxheight, imagewidth, imageheight, fname))

    all_ids = set(all_ids)
    all_ids_ann = set(all_ids_ann)
    no_annotations = list(all_ids - all_ids_ann)
    # Output images without any annotations
    for image_id in no_annotations:
        #print(no_annotations)
        # get the filename from id and filename dictionary
        values = list(sdict.keys())
        index = values.index(image_id)
        #print(index)
        # Get the key from the dictionary using the index
        imagefilename = list(sdict.values())[index]
        
        # Get Class label by splitting the filename
        classlabel = imagefilename.rsplit('/', 1)[0]
         
        out.write('{},{},{},{},{},{},{},{},{},{},{}\n'.format(image_id, -1, -1, -1, -1, classlabel , -1 , -1,-1, -1, imagefilename))
    out.close()

    # Sort file by image id
    s1 = pd.read_csv(out_file)
    s1.sort_values('id', inplace=True)
    s1.to_csv(out_file, index=False)

# %%
""""
convert_coco_json_to_csv('TBX11K_train_only_tb.json')

# %%
""""
#x_test
x_train = pd.read_csv ('/kaggle/working/TBX11K_train_only_tb.csv')

#id	image_id	category_id	iscrowd	area	bbox	width	height
#0	1	1	1	0	1793	[381.8337097167969, 126.8733901977539, 40.2369...	512	512
#1	2	2	2	0	19866	[307.3073425292969, 62.050445556640625, 135.50...	512	512

# %%
x_train.count()
#x_train.class_name.unique()

# %%
""""
x_train_backup = x_train
x_train['newclass_name'] = x_train['class_name']
x_train.loc[x_train['class_name'] == 'ObsoletePulmonaryTuberculosis', 'newclass_name'] =  1
x_train.loc[x_train['class_name'] == 'ActiveTuberculosis', 'newclass_name'] =  0

# %%
""""
# Round x1, x2, y1, and y2 columns to two decimal places
x_train['x1'] = x_train['x1'].round(2)
x_train['x2'] = x_train['x2'].round(2)
x_train['y1'] = x_train['y1'].round(2)
x_train['y2'] = x_train['y2'].round(2)

# Concatenate x1, y1, x2, and y2 into a bbox column with square brackets
x_train['bbox'] = x_train.apply(lambda row: f"[{row['x1']},{row['y1']},{row['x2']},{row['y2']}]", axis=1)

x_train.head()

# %%
""""
# Drop x1, y1, x2, and y2 columns if needed
x_train = x_train.drop(columns=['x1', 'y1', 'x2', 'y2'])

# %%
"""""
x_train = x_train.drop(columns=['class_name'])
x_train.head()

# %% [raw]
# """"""
# #y_train = x_train['newclass_name']
#
# y_train=x_train['newclass_name']
#
# #x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.1,random_state=1,stratify = Y)
# #Counter(list(y_train["category_id"]))

# %%
""""
x_train = x_train.drop(columns=['newclass_name'])
x_train.head(2)

# %%
x_train.count()
# Out:
# id             811
# image_id       811
# category_id    811
# iscrowd        811
# area           811
# bbox           811
# width          811
# height         811
# dtype: int64

# %%
y_train
# Out:
#      category_id
# 282            1
# 147            1
# 176            1
# 594            1
# 545            1
# ..           ...
# 690            1
# 73             1
# 875            2
# 242            1
# 640            1
#
# [811 rows x 1 columns]

# %%
#y_train.groupby('category_id').count()

y_train.category_id.value_counts()
# Out:
# 1    651
# 2    160
# Name: category_id, dtype: int64

# %%
# SMOTE 
#Before SMOTE :  Counter({1: 651, 2: 160})
#After SMOTE :  Counter({1: 651, 2: 651})

# SMOTE ADASYN
#Before ADASYN SMOTE :  Counter({1: 651, 2: 160})
#length of X_TRAIN :  811
#After ADASYN SMOTE :  Counter({2: 680, 1: 651})
#length of X_SMOTE :  1331

# %%
Counter(y_train.category_id)
# Out:
# Counter({1: 651, 2: 160})

# %%
from collections import Counter
from imblearn.over_sampling import ADASYN
counter_bef = Counter(y_train.category_id)
print("Before ADASYN SMOTE : ",counter_bef)
print("length of X_TRAIN : " , len(x_train['id']))
# Using the SOMTE to inflate the imbanlanced data, such as 'Belt'
x_train_only_id = pd.DataFrame(x_train['id'])
X_SMOTE, Y_SMOTE = ADASYN().fit_resample(x_train_only_id.values,y_train.values)
Counter(Y_SMOTE)

counter = Counter(Y_SMOTE)
print("After ADASYN SMOTE : ", counter)
print("length of X_SMOTE : " , len(X_SMOTE))
# Out:
# Before ADASYN SMOTE :  Counter({1: 651, 2: 160})
# length of X_TRAIN :  811
# After ADASYN SMOTE :  Counter({2: 680, 1: 651})
# length of X_SMOTE :  1331

# %%
x_train_only_id.count()

# %%
len(X_SMOTE)
# Out:
# 1331

# %%
# !pwd

# %%
x_train.head(2)

# %%
df_annid = pd.DataFrame(X_SMOTE,columns=['ann_id'])
df_annid.count()
# Out:
# ann_id    1331
# dtype: int64

# %%
#data["images"]

# %%
dict_annid[512]

# %%
# Storing some dictionaries, {annotation_id:nubers}; {image_id:images in train.json}
df_annid = pd.DataFrame(X_SMOTE,columns=['ann_id'])
print(df_annid.head())
# Storing the inflated annotations
dict_annid = {}
for i,row in df_annid.iterrows():
    annid = row['ann_id']
    if annid in dict_annid:
        dict_annid[annid] += 1
    else:
        dict_annid[annid] = 1
#print(dict_annid)
# Storing the imageid and its json data
dict_imgid = {}
for img in data["images"]:
    id = img['id']
    #print("Image id : ",img['id'])
    dict_imgid[id] = img
#print(dict_imgid[id])
    
#Image id :  1
#Image id :  2
#Image id :  3
#Image id :  4
# Out:
#    ann_id
# 0     283
# 1     148
# 2     177
# 3     595
# 4     546

# %%
#dict_annid

#283: 2,
 #148: 1,
 #177: 1,
 #595: 2,
 #546: 1,
 #741: 1,

# %%
len(dict_annid)
# Out:
# 843

# %%
len(dict_imgid)
# Out:
# 599

# %%
""""
dict_imgid

{1: {'id': 1,
  'file_name': 'tb/tb0005.png',
  'width': 512,
  'height': 512,
  'date_captured': '2020-06-24 12:42:40.548139',
  'license': 1,
  'coco_url': '',
  'flickr_url': ''},
""""

# %%
data_new ={}

data_new['categories']= [{'id': 1, 'name': 'ActiveTuberculosis', 'supercategory': 'Tuberculosis'},
 {'id': 2,
  'name': 'ObsoletePulmonaryTuberculosis',
  'supercategory': 'Tuberculosis'}]

# %%
# Transfer the categories to continuous ids
cate_id_map = {}
for i, category in enumerate(data_new['categories']):     
    cate_id_map[category['id']] = i
    #id_cat[i] = category['id']
cate_id_map
# Out:
# {1: 0, 2: 1}

# %%
# convert the bounding box from COCO to YOLO format.
def cc2yolo_bbox(img_width, img_height, bbox):
    dw = 1. / img_width
    dh = 1. / img_height
    x = bbox[0] + bbox[2] / 2.0
    y = bbox[1] + bbox[3] / 2.0
    w = bbox[2]
    h = bbox[3]
 
    x = x * dw
    w = w * dw
    y = y * dh
    h = h * dh
    return (x, y, w, h)

# %%
# Create the path for storing the txt files for yolov5
yolo_anno_path = '/kaggle/working/training/yolo_anno/'
if not os.path.exists(yolo_anno_path):
    os.makedirs(yolo_anno_path)

# %%
data['annotations'][0]
# Out:
# {'id': 1,
#  'image_id': 1,
#  'category_id': 1,
#  'iscrowd': 0,
#  'area': 1793,
#  'bbox': [381.8337097167969,
#   126.8733901977539,
#   40.236907958984375,
#   44.565773010253906],
#  'width': 512,
#  'height': 512}

# %%
dict_imgid[1]
# Out:
# {'id': 1,
#  'file_name': 'tb/tb0005.png',
#  'width': 512,
#  'height': 512,
#  'date_captured': '2020-06-24 12:42:40.548139',
#  'license': 1,
#  'coco_url': '',
#  'flickr_url': ''}

# %%
#dict_imgid

{1: {'id': 1,
  'file_name': 'tb/tb0005.png',
  'width': 512,
  'height': 512,
  'date_captured': '2020-06-24 12:42:40.548139',
  'license': 1,
  'coco_url': '',
  'flickr_url': ''},
 2: {'id': 2,
# Out:
#   Cell In[53], line 11
#     2: {'id': 2,
#                 ^
# SyntaxError: incomplete input

# %%
# Building the train and validation images list
dict_imgid_count = {} # this dictionary records how many images are the same
f = open('/kaggle/working/train_valid.csv','w')
f.write('id,file_name,split\n')
for i in tqdm(range(len(data['annotations']))):
    annid = data['annotations'][i]['id']
    img_id = data['annotations'][i]['image_id']    
    filename = dict_imgid[img_id]['file_name']
    #print(filename)
    yolo_txt_name = filename.split('.')[0] + '.txt' #remove .jpg
    yolo_txt_name = yolo_txt_name.split('/')[1]
    img_width = dict_imgid[img_id]['width']
    img_height = dict_imgid[img_id]['height']
    if annid in dict_annid:
        temp_count = 1
        if img_id in dict_imgid_count:
            dict_imgid_count[img_id] += 1
            temp_count = dict_imgid_count[img_id]
        else:
            dict_imgid_count[img_id] = 1        
        arr = str(filename).split('.')
        filename = arr[0] + '_' + str(temp_count) + '.' + arr[1]
        f.write('{},{},train\n'.format(img_id, filename))    
    
    yolo_txt_file = open(os.path.join(yolo_anno_path, yolo_txt_name), 'w')    
    for anno in data['annotations']:
        if anno['image_id'] == img_id:
            yolo_bbox = cc2yolo_bbox(img_width, img_height, anno['bbox']) # "bbox": [x,y,width,height]        
            yolo_txt_file.write('{} {} {} {} {}\n'.format(cate_id_map[anno['category_id']], yolo_bbox[0], yolo_bbox[1], yolo_bbox[2], yolo_bbox[3]))
    yolo_txt_file.close()

# write validation files into the file train.csv
for i,row in x_test.iterrows():
    img_id = row['image_id']
    filename = dict_imgid[img_id]['file_name']
    f.write('{},{},valid\n'.format(img_id, filename))

f.close()
# Out:
# 100%|██████████| 902/902 [00:00<00:00, 4543.72it/s]

# %%
x_test.head(2)
# Out:
#       id  image_id  category_id  iscrowd   area  \
# 430  431       287            1        0  17693
# 378  379       255            1        0  19797
#
#                                                   bbox  width  height
# 430  [327.72393798828125, 78.5093994140625, 137.823...    512     512
# 378  [280.4891662597656, 64.58258819580078, 117.748...    512     512

# %%
# Then we got the training and tesing dataframe
df = pd.read_csv('/kaggle/working/train_valid.csv')
print(df)
# Out:
#       id        file_name  split
# 0      1  tb/tb0005_1.png  train
# 1      2  tb/tb0007_1.png  train
# 2      2  tb/tb0007_2.png  train
# 3      3  tb/tb0012_1.png  train
# 4      4  tb/tb0017_1.png  train
# ..   ...              ...    ...
# 929  469    tb/tb0925.png  valid
# 930   22    tb/tb0050.png  valid
# 931  495    tb/tb0983.png  valid
# 932  132    tb/tb0262.png  valid
# 933  436    tb/tb0865.png  valid
#
# [934 rows x 3 columns]

# %%
row = df.loc[5]
print(row)
name_count = row.file_name.split('.')[0]
print("name count : ", name_count)
name = name_count.split('_')[0]
print("name : ", name)
name = name_count.split('/')[1]
print(name)
#name = name_count.split('_')[0]
    #if i<10:
# Out:
# id                         5
# file_name    tb/tb0018_1.png
# split                  train
# Name: 5, dtype: object
# name count :  tb/tb0018_1
# name :  tb/tb0018
# tb0018_1

# %%
row = df.loc[5]
print(row)
#name = row.file_name.split('.')[0]
name_file = row.file_name.split('/')[1]
print("name file : ", name_file)
name_count = name_file.split('.')[0]
print("name count : ", name_count)
name = name_count.split('_')[0]
print("name  : ", name)
# Out:
# id                         5
# file_name    tb/tb0018_1.png
# split                  train
# Name: 5, dtype: object
# name file :  tb0018_1.png
# name count :  tb0018_1
# name  :  tb0018

# %%
# Preparing the data and structure directories for Yolov5
os.makedirs('/kaggle/working/training/images/train', exist_ok=True)
os.makedirs('/kaggle/working/training/images/valid', exist_ok=True)
#
os.makedirs('/kaggle/working/training/labels/train', exist_ok=True)
os.makedirs('/kaggle/working/training/labels/valid', exist_ok=True)

# %%
# copy the image files and annotations txt files to relevant folders
for i in tqdm(range(len(df))):
    row = df.loc[i]
    #name = row.file_name.split('.')[0]
    name_file = row.file_name.split('/')[1]
    name_count = name_file.split('.')[0]
    name = name_count.split('_')[0]
    
    #if i<10:
    #    print(name)
    if row.split == 'train':        
        copyfile(f'/kaggle/input/tbx-11/TBX11K/imgs/tb/{name}.png', f'/kaggle/working/training/images/train/{name_count}.png')
        copyfile(f'/kaggle/working/training/yolo_anno/{name}.txt', f'/kaggle/working/training/labels/train/{name_count}.txt')
    else:        
        copyfile(f'/kaggle/input/tbx-11/TBX11K/imgs/tb/{name}.png', f'/kaggle/working/training/images/valid/{name}.png')
        copyfile(f'/kaggle/working/training/yolo_anno/{name}.txt', f'/kaggle/working/training/labels/valid/{name}.txt')
# Out:
# 100%|██████████| 934/934 [00:09<00:00, 96.50it/s]

# %%
# Let's install Yolov5 to exploring a wonderful trip 
# %cd /kaggle/working
# !git clone https://github.com/ultralytics/yolov5
# %cd /kaggle/working/yolov5
# %pip install -r requirements.txt
# Out:
# /kaggle/working
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15937, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 15937 (delta 26), reused 37 (delta 16), pack-reused 15880
# Receiving objects: 100% (15937/15937), 14.60 MiB | 25.43 MiB/s, done.
# Resolving deltas: 100% (10925/10925), done.
# /kaggle/working/yolov5
# Requirement already satisfied: gitpython>=3.1.30 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.1.31)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (9.5.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (5.9.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (1.11.1)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.15.1)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (4.65.0)
# Collecting ultralytics>=8.0.147 (from -r requirements.txt (line 18))
#   Downloading ultralytics-8.0.168-py3-none-any.whl (613 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.8/613.8 kB 15.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.12.2)
# Collecting setuptools>=65.5.1 (from -r requirements.txt (line 42))
#   Downloading setuptools-68.1.2-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.1/805.1 kB 38.9 MB/s eta 0:00:00
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2023.5.7)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics>=8.0.147->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Installing collected packages: setuptools, thop, ultralytics
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 59.8.0
#     Uninstalling setuptools-59.8.0:
#       Successfully uninstalled setuptools-59.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-api 1.18.0 requires importlib-metadata~=6.0.0, but you have importlib-metadata 6.7.0 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.1 which is incompatible.
# Successfully installed setuptools-68.1.2 thop-0.1.1.post2209072238 ultralytics-8.0.168
# Note: you may need to restart the kernel to use updated packages.

# %%
# Firstly we create the yaml file
data_yaml = dict(
    train = '/kaggle/working/training/images/train/',
    val = '/kaggle/working/training/images/valid/',
    nc = 5,
    names = ['ActiveTuberculosis', 'ObsoletePulmonaryTuberculosis']
)

# we will make the file under the yolov5/data/ directory.
with open('/kaggle/working/yolov5/data/data.yaml', 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=True)
    
# %cat /kaggle/working/yolov5/data/data.yaml # show your YAML file
# Out:
# {names: [ActiveTuberculosis, ObsoletePulmonaryTuberculosis], nc: 5, train: /kaggle/working/training/images/train/,
#   val: /kaggle/working/training/images/valid/}

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# For showing the example code, I only select yolov5s model and 1 epoch to run.
BATCH_SIZE = 16
EPOCHS = 10 
MODEL = 'yolov5m.pt' # this specify the model for training, you can use yolov5s.pt, yolov5l.pt, yolov5x.pt, etc.

# %%
# GO TRAIN
# !python train.py --batch {BATCH_SIZE} \
                 --epochs {EPOCHS} \
                 --data data.yaml \
                 --weights {MODEL} \
                 --project tbx_smote\
                 --name tbx_smote_medium_ADASYN
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Currently logged in as: rachana4lg (rachmsupgradljmu). Use `wandb login --relogin` to force relogin
# train: weights=yolov5m.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=tbx_smote, name=tbx_smote_medium_ADASYN, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-213-g378ed74 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir tbx_smote', view at http://localhost:6006/
# wandb: wandb version 0.15.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.5
# wandb: Run data is saved locally in /kaggle/working/yolov5/wandb/run-20230901_210846-gvti51cd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tbx_smote_medium_ADASYN
# wandb: ⭐️ View project at https://wandb.ai/rachmsupgradljmu/tbx_smote
# wandb: 🚀 View run at https://wandb.ai/rachmsupgradljmu/tbx_smote/runs/gvti51cd
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 24.2MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m.pt to yolov5m.pt...
# 100%|██████████████████████████████████████| 40.8M/40.8M [00:00<00:00, 74.2MB/s]
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     28287  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model summary: 291 layers, 20875359 parameters, 20875359 gradients, 48.2 GFLOPs
#
# Transferred 475/481 items from yolov5m.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.0005), 82 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /kaggle/working/training/labels/train... 843 images, 0 backgroun
# train: New cache created: /kaggle/working/training/labels/train.cache
# val: Scanning /kaggle/working/training/labels/valid... 89 images, 0 backgrounds,
# val: New cache created: /kaggle/working/training/labels/valid.cache
#
# AutoAnchor: 4.91 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to tbx_smote/tbx_smote_medium_ADASYN/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to tbx_smote/tbx_smote_medium_ADASYN
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         0/9      7.11G    0.09072    0.03396    0.02641         22        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.552      0.186     0.0492     0.0129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         1/9      7.11G    0.06649    0.03172    0.02048         30        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.622      0.191      0.127     0.0384
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         2/9      7.11G    0.06031    0.02767    0.01905         27        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.665      0.246      0.177     0.0634
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         3/9      7.12G    0.05672    0.02631    0.01945         30        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.696      0.314      0.232     0.0889
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         4/9      7.12G    0.05168    0.02652    0.01901         28        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.817      0.302      0.336      0.133
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         5/9      7.12G    0.04857    0.02413    0.01799         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.817      0.292       0.35      0.134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         6/9      7.12G    0.04562    0.02519    0.01741         33        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.826      0.357      0.424      0.161
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         7/9      7.12G    0.04345    0.02411    0.01722         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.866      0.386       0.48      0.226
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         8/9      7.12G    0.04117    0.02245    0.01656         33        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147       0.43      0.519      0.484      0.238
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         9/9      7.12G    0.04014    0.02246    0.01548         32        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.417      0.632      0.534      0.271
#
# 10 epochs completed in 0.109 hours.
# Optimizer stripped from tbx_smote/tbx_smote_medium_ADASYN/weights/last.pt, 42.2MB
# Optimizer stripped from tbx_smote/tbx_smote_medium_ADASYN/weights/best.pt, 42.2MB
#
# Validating tbx_smote/tbx_smote_medium_ADASYN/weights/best.pt...
# Fusing layers...
# Model summary: 212 layers, 20856975 parameters, 0 gradients, 47.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.419      0.631      0.534      0.271
#     ActiveTuberculosis         89        118      0.572      0.918       0.85      0.454
# ObsoletePulmonaryTuberculosis         89         29      0.266      0.345      0.218      0.088
# Results saved to tbx_smote/tbx_smote_medium_ADASYN
# wandb: Waiting for W&B process to finish... (success).
# wandb: - 44.709 MB of 45.663 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:      metrics/mAP_0.5 ▁▂▃▄▅▅▆▇▇██
# wandb: metrics/mAP_0.5:0.95 ▁▂▂▃▄▄▅▇▇██
# wandb:    metrics/precision ▃▄▅▅▇▇▇█▁▁▁
# wandb:       metrics/recall ▁▁▂▃▃▃▄▄▆██
# wandb:       train/box_loss █▅▄▃▃▂▂▁▁▁
# wandb:       train/cls_loss █▄▃▄▃▃▂▂▂▁
# wandb:       train/obj_loss █▇▄▃▃▂▃▂▁▁
# wandb:         val/box_loss █▆▆▅▃▃▃▂▁▁▁
# wandb:         val/cls_loss █▅▇▆▅▅▅▄▂▁▁
# wandb:         val/obj_loss █▆▄▄▃▃▃▂▂▁▁
# wandb:                x/lr0 █▅▂▂▂▁▁▁▁▁
# wandb:                x/lr1 ▂▆█▇▇▆▅▃▂▁
# wandb:                x/lr2 ▂▆█▇▇▆▅▃▂▁
# wandb:
# wandb: Run summary:
# wandb:           best/epoch 9
# wandb:         best/mAP_0.5 0.53449
# wandb:    best/mAP_0.5:0.95 0.27111
# wandb:       best/precision 0.41728
# wandb:          best/recall 0.63152
# wandb:      metrics/mAP_0.5 0.53417
# wandb: metrics/mAP_0.5:0.95 0.27088
# wandb:    metrics/precision 0.41891
# wandb:       metrics/recall 0.63144
# wandb:       train/box_loss 0.04014
# wandb:       train/cls_loss 0.01548
# wandb:       train/obj_loss 0.02246
# wandb:         val/box_loss 0.03878
# wandb:         val/cls_loss 0.01337
# wandb:         val/obj_loss 0.01149
# wandb:                x/lr0 0.00208
# wandb:                x/lr1 0.00208
# wandb:                x/lr2 0.00208
# wandb:
# wandb: 🚀 View run tbx_smote_medium_ADASYN at: https://wandb.ai/rachmsupgradljmu/tbx_smote/runs/gvti51cd
# wandb: Synced 6 W&B file(s), 17 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230901_210846-gvti51cd/logs
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.

# %%
# For showing the example code, I only select yolov5s model and 1 epoch to run.
BATCH_SIZE = 16
EPOCHS = 10 
MODEL = 'yolov5l.pt'

# %%
# GO TRAIN
# !python train.py --batch {BATCH_SIZE} \
                 --epochs {EPOCHS} \
                 --data data.yaml \
                 --weights {MODEL} \
                 --project tbx_smote\
                 --name tbx_smote_large_ADASYN
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Currently logged in as: rachana4lg (rachmsupgradljmu). Use `wandb login --relogin` to force relogin
# train: weights=yolov5l.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=tbx_smote, name=tbx_smote_large_ADASYN, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-213-g378ed74 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir tbx_smote', view at http://localhost:6006/
# wandb: wandb version 0.15.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.5
# wandb: Run data is saved locally in /kaggle/working/yolov5/wandb/run-20230901_213624-45mqu74u
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tbx_smote_large_ADASYN
# wandb: ⭐️ View project at https://wandb.ai/rachmsupgradljmu/tbx_smote
# wandb: 🚀 View run at https://wandb.ai/rachmsupgradljmu/tbx_smote/runs/45mqu74u
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5l.pt to yolov5l.pt...
# 100%|██████████████████████████████████████| 89.3M/89.3M [00:01<00:00, 57.5MB/s]
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     37695  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model summary: 368 layers, 46143679 parameters, 46143679 gradients, 108.2 GFLOPs
#
# Transferred 607/613 items from yolov5l.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 101 weight(decay=0.0), 104 weight(decay=0.0005), 104 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /kaggle/working/training/labels/train.cache... 843 images, 0 bac
# val: Scanning /kaggle/working/training/labels/valid.cache... 89 images, 0 backgr
#
# AutoAnchor: 4.91 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to tbx_smote/tbx_smote_large_ADASYN/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to tbx_smote/tbx_smote_large_ADASYN
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         0/9      9.05G     0.0884    0.03747    0.02493         22        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.566      0.169     0.0741     0.0222
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         1/9      10.1G    0.06666    0.03252    0.02031         30        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.639      0.199      0.124     0.0387
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         2/9      10.1G    0.05985    0.02785    0.01886         27        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.661      0.186      0.145     0.0427
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         3/9      10.1G    0.05565    0.02605    0.01926         30        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147       0.76       0.28      0.243     0.0787
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         4/9      10.1G    0.05049    0.02589    0.01862         28        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.739      0.258      0.309      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         5/9      10.1G    0.04691    0.02412    0.01759         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.845      0.322      0.369      0.166
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         6/9      10.1G    0.04465    0.02475    0.01655         33        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.342      0.437      0.442      0.207
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         7/9      10.1G     0.0424    0.02386    0.01537         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.331      0.527      0.482      0.242
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         8/9      10.1G    0.04028    0.02227    0.01493         33        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.381        0.6      0.547      0.276
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         9/9      10.1G    0.03874    0.02208    0.01258         32        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.558      0.647      0.658       0.32
#
# 10 epochs completed in 0.130 hours.
# Optimizer stripped from tbx_smote/tbx_smote_large_ADASYN/weights/last.pt, 92.9MB
# Optimizer stripped from tbx_smote/tbx_smote_large_ADASYN/weights/best.pt, 92.9MB
#
# Validating tbx_smote/tbx_smote_large_ADASYN/weights/best.pt...
# Fusing layers...
# Model summary: 267 layers, 46113663 parameters, 0 gradients, 107.7 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         89        147      0.559      0.648      0.658      0.321
#     ActiveTuberculosis         89        118      0.601       0.89      0.868      0.433
# ObsoletePulmonaryTuberculosis         89         29      0.517      0.406      0.448      0.208
# Results saved to tbx_smote/tbx_smote_large_ADASYN
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:      metrics/mAP_0.5 ▁▂▂▃▄▅▅▆▇██
# wandb: metrics/mAP_0.5:0.95 ▁▁▁▂▃▄▅▆▇██
# wandb:    metrics/precision ▄▅▅▇▇█▁▁▂▄▄
# wandb:       metrics/recall ▁▁▁▃▂▃▅▆▇██
# wandb:       train/box_loss █▅▄▃▃▂▂▂▁▁
# wandb:       train/cls_loss █▅▅▅▄▄▃▃▂▁
# wandb:       train/obj_loss █▆▄▃▃▂▂▂▁▁
# wandb:         val/box_loss █▇▇▇▄▃▂▁▁▁▁
# wandb:         val/cls_loss █▇▇█▇▅▅▄▄▁▁
# wandb:         val/obj_loss █▃▃▃▅▃▂▂▁▁▁
# wandb:                x/lr0 █▅▂▂▂▁▁▁▁▁
# wandb:                x/lr1 ▂▆█▇▇▆▅▃▂▁
# wandb:                x/lr2 ▂▆█▇▇▆▅▃▂▁
# wandb:
# wandb: Run summary:
# wandb:           best/epoch 9
# wandb:         best/mAP_0.5 0.65803
# wandb:    best/mAP_0.5:0.95 0.31963
# wandb:       best/precision 0.55813
# wandb:          best/recall 0.64689
# wandb:      metrics/mAP_0.5 0.65835
# wandb: metrics/mAP_0.5:0.95 0.32058
# wandb:    metrics/precision 0.55891
# wandb:       metrics/recall 0.64809
# wandb:       train/box_loss 0.03874
# wandb:       train/cls_loss 0.01258
# wandb:       train/obj_loss 0.02208
# wandb:         val/box_loss 0.03975
# wandb:         val/cls_loss 0.00766
# wandb:         val/obj_loss 0.0116
# wandb:                x/lr0 0.00208
# wandb:                x/lr1 0.00208
# wandb:                x/lr2 0.00208
# wandb:
# wandb: 🚀 View run tbx_smote_large_ADASYN at: https://wandb.ai/rachmsupgradljmu/tbx_smote/runs/45mqu74u
# wandb: Synced 6 W&B file(s), 17 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230901_213624-45mqu74u/logs
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.

# %% [markdown]
# # Inference

# %%
# !cp -R /kaggle/input/tbx-11/TBX11K/annotations/json/TBX11K_val_only_tb.json /kaggle/working/

# %%
# %cd ..
# !pwd
# Out:
# /kaggle/working
# /kaggle/working

# %%
convert_coco_json_to_csv('/kaggle/working/TBX11K_val_only_tb.json')

# %%
df_rach = pd.read_csv('/kaggle/working/TBX11K_val_only_tb.csv')

# %%
df_rach.columns = df_rach.columns.str.replace(' ', '')

# %%
df_rach.columns
# Out:
# Index(['id', 'x1', 'y1', 'x2', 'y2', 'class_name', 'boxwidth', 'boxheight',
#        'imagewidth', 'imageheight', 'file_name'],
#       dtype='object')

# %%
df_rach['file_name']
# Out:
# 0      tb/tb0003.png
# 1      tb/tb0003.png
# 2      tb/tb0004.png
# 3      tb/tb0004.png
# 4      tb/tb0006.png
#            ...
# 304    tb/tb1183.png
# 305    tb/tb1188.png
# 306    tb/tb1188.png
# 307    tb/tb1192.png
# 308    tb/tb1192.png
# Name: file_name, Length: 309, dtype: object

# %%
df_rach['file_name_new'] = df_rach['file_name'].str.split('/').str[1]
df_rach.head(2)
# Out:
#    id          x1         y1          x2          y2  \
# 0   1  259.687317  44.277679  360.825348  183.189606
# 1   1  110.414085  69.814293  211.191544  182.465164
#
#                       class_name    boxwidth   boxheight  imagewidth  \
# 0  ObsoletePulmonaryTuberculosis  101.138031  138.911926         512
# 1  ObsoletePulmonaryTuberculosis  100.777458  112.650871         512
#
#    imageheight      file_name file_name_new
# 0          512  tb/tb0003.png    tb0003.png
# 1          512  tb/tb0003.png    tb0003.png

# %%
#df_rach[['id','file_name_new' ]]

# %%
# In the Dev phase, we will only use the valid data for predicition. 
# Don't forget change it to test data in the Final pahse.
#valid_df = pd.read_csv('/kaggle/input/c/cowboyoutfits/valid.csv')
#test_df = pd.read_csv('/kaggle/input/c/cowboyoutfits/test.csv')

valid_df = df_rach[['id','file_name_new' ]]
valid_df.head()
# Out:
#    id file_name_new
# 0   1    tb0003.png
# 1   1    tb0003.png
# 2   2    tb0004.png
# 3   2    tb0004.png
# 4   3    tb0006.png

# %%
# make directory to store the validation data.
os.makedirs('/kaggle/working/inference/valid', exist_ok=True)
os.makedirs('/kaggle/working/inference/test', exist_ok=True)

# %%
# copy the validation image to inference folder for detection process
for i in tqdm(range(len(valid_df))):
    row = valid_df.loc[i]    
    name = row.file_name_new.split('.')[0]
    copyfile(f'/kaggle/input/tbx-11/TBX11K/imgs/tb/{name}.png', f'/kaggle/working/inference/valid/{name}.png')
# Out:
# 100%|██████████| 309/309 [00:03<00:00, 96.11it/s]

# %%
VALID_PATH = '/kaggle/working/inference/valid/'
#MODEL_PATH = '/kaggle/working/yolo/cowboy-detection/exp5/weights/best.pt'
#MODEL_PATH = '/kaggle/input/bestmodelweights/exp8-m-100ep-withonesplit-best.pt'
MODEL_PATH  =  '/kaggle/working/yolov5/tbx_smote/tbx_smote_large_ADASYN/weights/best.pt'
#IMAGE_PATH = '/kaggle/input/cowboyoutfits/images/'

# %%
#%cd ..
# !pwd
# Out:
# /kaggle/working/yolov5

# %%
# %cd /kaggle/working/yolov5
# Out:
# /kaggle/working/yolov5

# %%
# Let's begin the amazing time to detect the cowboy outfits objects
# !python detect.py --weights {MODEL_PATH} \
                  --source {VALID_PATH} \
                  --conf 0.20 \
                  --iou-thres 0.45 \
                  --save-txt \
                  --save-conf \
                  --augment
# Out:
# detect: weights=['/kaggle/working/yolov5/tbx_smote/tbx_smote_large_ADASYN/weights/best.pt'], source=/kaggle/working/inference/valid/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=True, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-213-g378ed74 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46113663 parameters, 0 gradients, 107.7 GFLOPs
# image 1/200 /kaggle/working/inference/valid/tb0003.png: 640x640 2 ActiveTuberculosiss, 105.6ms
# image 2/200 /kaggle/working/inference/valid/tb0004.png: 640x640 4 ActiveTuberculosiss, 51.8ms
# image 3/200 /kaggle/working/inference/valid/tb0006.png: 640x640 2 ActiveTuberculosiss, 49.4ms
# image 4/200 /kaggle/working/inference/valid/tb0009.png: 640x640 2 ActiveTuberculosiss, 48.6ms
# image 5/200 /kaggle/working/inference/valid/tb0014.png: 640x640 2 ActiveTuberculosiss, 48.7ms
# image 6/200 /kaggle/working/inference/valid/tb0015.png: 640x640 1 ActiveTuberculosis, 48.5ms
# image 7/200 /kaggle/working/inference/valid/tb0019.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 8/200 /kaggle/working/inference/valid/tb0024.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 9/200 /kaggle/working/inference/valid/tb0029.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 10/200 /kaggle/working/inference/valid/tb0032.png: 640x640 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 11/200 /kaggle/working/inference/valid/tb0033.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 12/200 /kaggle/working/inference/valid/tb0090.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 13/200 /kaggle/working/inference/valid/tb0096.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 14/200 /kaggle/working/inference/valid/tb0103.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 15/200 /kaggle/working/inference/valid/tb0108.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 16/200 /kaggle/working/inference/valid/tb0124.png: 640x640 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 17/200 /kaggle/working/inference/valid/tb0134.png: 640x640 3 ActiveTuberculosiss, 48.5ms
# image 18/200 /kaggle/working/inference/valid/tb0135.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 19/200 /kaggle/working/inference/valid/tb0145.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 20/200 /kaggle/working/inference/valid/tb0147.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 21/200 /kaggle/working/inference/valid/tb0155.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 22/200 /kaggle/working/inference/valid/tb0156.png: 640x640 3 ActiveTuberculosiss, 48.5ms
# image 23/200 /kaggle/working/inference/valid/tb0162.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 24/200 /kaggle/working/inference/valid/tb0183.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 25/200 /kaggle/working/inference/valid/tb0191.png: 640x640 1 ActiveTuberculosis, 48.5ms
# image 26/200 /kaggle/working/inference/valid/tb0196.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 27/200 /kaggle/working/inference/valid/tb0201.png: 640x640 2 ActiveTuberculosiss, 2 ObsoletePulmonaryTuberculosiss, 48.5ms
# image 28/200 /kaggle/working/inference/valid/tb0206.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 29/200 /kaggle/working/inference/valid/tb0208.png: 640x640 3 ActiveTuberculosiss, 48.5ms
# image 30/200 /kaggle/working/inference/valid/tb0223.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 31/200 /kaggle/working/inference/valid/tb0231.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 32/200 /kaggle/working/inference/valid/tb0234.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 33/200 /kaggle/working/inference/valid/tb0239.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 34/200 /kaggle/working/inference/valid/tb0241.png: 640x640 (no detections), 48.4ms
# image 35/200 /kaggle/working/inference/valid/tb0252.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 36/200 /kaggle/working/inference/valid/tb0256.png: 640x640 5 ActiveTuberculosiss, 48.4ms
# image 37/200 /kaggle/working/inference/valid/tb0264.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 38/200 /kaggle/working/inference/valid/tb0266.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 39/200 /kaggle/working/inference/valid/tb0274.png: 640x640 2 ActiveTuberculosiss, 2 ObsoletePulmonaryTuberculosiss, 48.4ms
# image 40/200 /kaggle/working/inference/valid/tb0286.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 41/200 /kaggle/working/inference/valid/tb0287.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 42/200 /kaggle/working/inference/valid/tb0297.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 43/200 /kaggle/working/inference/valid/tb0326.png: 640x640 1 ActiveTuberculosis, 48.5ms
# image 44/200 /kaggle/working/inference/valid/tb0329.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 45/200 /kaggle/working/inference/valid/tb0338.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 46/200 /kaggle/working/inference/valid/tb0343.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 47/200 /kaggle/working/inference/valid/tb0345.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 48/200 /kaggle/working/inference/valid/tb0348.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 49/200 /kaggle/working/inference/valid/tb0352.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 50/200 /kaggle/working/inference/valid/tb0356.png: 640x640 4 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 51/200 /kaggle/working/inference/valid/tb0357.png: 640x640 1 ActiveTuberculosis, 1 ObsoletePulmonaryTuberculosis, 57.1ms
# image 52/200 /kaggle/working/inference/valid/tb0362.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 53/200 /kaggle/working/inference/valid/tb0365.png: 640x640 3 ActiveTuberculosiss, 48.5ms
# image 54/200 /kaggle/working/inference/valid/tb0370.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 55/200 /kaggle/working/inference/valid/tb0372.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 56/200 /kaggle/working/inference/valid/tb0389.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 57/200 /kaggle/working/inference/valid/tb0393.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 58/200 /kaggle/working/inference/valid/tb0397.png: 640x640 1 ActiveTuberculosis, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 59/200 /kaggle/working/inference/valid/tb0402.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 60/200 /kaggle/working/inference/valid/tb0404.png: 640x640 5 ActiveTuberculosiss, 48.4ms
# image 61/200 /kaggle/working/inference/valid/tb0408.png: 640x640 (no detections), 48.4ms
# image 62/200 /kaggle/working/inference/valid/tb0413.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 63/200 /kaggle/working/inference/valid/tb0433.png: 640x640 1 ActiveTuberculosis, 1 ObsoletePulmonaryTuberculosis, 48.5ms
# image 64/200 /kaggle/working/inference/valid/tb0446.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 65/200 /kaggle/working/inference/valid/tb0455.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 66/200 /kaggle/working/inference/valid/tb0456.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 67/200 /kaggle/working/inference/valid/tb0463.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 68/200 /kaggle/working/inference/valid/tb0465.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 69/200 /kaggle/working/inference/valid/tb0467.png: 640x640 (no detections), 48.4ms
# image 70/200 /kaggle/working/inference/valid/tb0469.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 71/200 /kaggle/working/inference/valid/tb0472.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 72/200 /kaggle/working/inference/valid/tb0473.png: 640x640 (no detections), 48.4ms
# image 73/200 /kaggle/working/inference/valid/tb0474.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 74/200 /kaggle/working/inference/valid/tb0485.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 75/200 /kaggle/working/inference/valid/tb0493.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 76/200 /kaggle/working/inference/valid/tb0494.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 77/200 /kaggle/working/inference/valid/tb0498.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 78/200 /kaggle/working/inference/valid/tb0500.png: 640x640 3 ObsoletePulmonaryTuberculosiss, 48.4ms
# image 79/200 /kaggle/working/inference/valid/tb0501.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 80/200 /kaggle/working/inference/valid/tb0503.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 81/200 /kaggle/working/inference/valid/tb0506.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 82/200 /kaggle/working/inference/valid/tb0507.png: 640x640 (no detections), 48.4ms
# image 83/200 /kaggle/working/inference/valid/tb0510.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 84/200 /kaggle/working/inference/valid/tb0514.png: 640x640 (no detections), 48.4ms
# image 85/200 /kaggle/working/inference/valid/tb0515.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 86/200 /kaggle/working/inference/valid/tb0521.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 87/200 /kaggle/working/inference/valid/tb0523.png: 640x640 1 ActiveTuberculosis, 2 ObsoletePulmonaryTuberculosiss, 48.4ms
# image 88/200 /kaggle/working/inference/valid/tb0526.png: 640x640 1 ActiveTuberculosis, 2 ObsoletePulmonaryTuberculosiss, 48.5ms
# image 89/200 /kaggle/working/inference/valid/tb0544.png: 640x640 1 ActiveTuberculosis, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 90/200 /kaggle/working/inference/valid/tb0548.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 91/200 /kaggle/working/inference/valid/tb0553.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 92/200 /kaggle/working/inference/valid/tb0555.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.5ms
# image 93/200 /kaggle/working/inference/valid/tb0563.png: 640x640 (no detections), 48.4ms
# image 94/200 /kaggle/working/inference/valid/tb0564.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 95/200 /kaggle/working/inference/valid/tb0566.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 96/200 /kaggle/working/inference/valid/tb0569.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 97/200 /kaggle/working/inference/valid/tb0575.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 98/200 /kaggle/working/inference/valid/tb0577.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 99/200 /kaggle/working/inference/valid/tb0582.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 100/200 /kaggle/working/inference/valid/tb0585.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 101/200 /kaggle/working/inference/valid/tb0606.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 102/200 /kaggle/working/inference/valid/tb0610.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 103/200 /kaggle/working/inference/valid/tb0619.png: 640x640 1 ActiveTuberculosis, 48.5ms
# image 104/200 /kaggle/working/inference/valid/tb0634.png: 640x640 1 ActiveTuberculosis, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 105/200 /kaggle/working/inference/valid/tb0635.png: 640x640 (no detections), 48.4ms
# image 106/200 /kaggle/working/inference/valid/tb0637.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 107/200 /kaggle/working/inference/valid/tb0638.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 108/200 /kaggle/working/inference/valid/tb0642.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 109/200 /kaggle/working/inference/valid/tb0644.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 110/200 /kaggle/working/inference/valid/tb0647.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 111/200 /kaggle/working/inference/valid/tb0659.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 112/200 /kaggle/working/inference/valid/tb0667.png: 640x640 (no detections), 48.4ms
# image 113/200 /kaggle/working/inference/valid/tb0668.png: 640x640 1 ActiveTuberculosis, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 114/200 /kaggle/working/inference/valid/tb0679.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 115/200 /kaggle/working/inference/valid/tb0680.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 116/200 /kaggle/working/inference/valid/tb0691.png: 640x640 (no detections), 48.4ms
# image 117/200 /kaggle/working/inference/valid/tb0695.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 118/200 /kaggle/working/inference/valid/tb0713.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 119/200 /kaggle/working/inference/valid/tb0716.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 120/200 /kaggle/working/inference/valid/tb0719.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 121/200 /kaggle/working/inference/valid/tb0725.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 122/200 /kaggle/working/inference/valid/tb0726.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 123/200 /kaggle/working/inference/valid/tb0733.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 124/200 /kaggle/working/inference/valid/tb0735.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 125/200 /kaggle/working/inference/valid/tb0743.png: 640x640 1 ActiveTuberculosis, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 126/200 /kaggle/working/inference/valid/tb0749.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 127/200 /kaggle/working/inference/valid/tb0751.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 128/200 /kaggle/working/inference/valid/tb0754.png: 640x640 2 ActiveTuberculosiss, 2 ObsoletePulmonaryTuberculosiss, 48.4ms
# image 129/200 /kaggle/working/inference/valid/tb0762.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 130/200 /kaggle/working/inference/valid/tb0767.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 131/200 /kaggle/working/inference/valid/tb0781.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 132/200 /kaggle/working/inference/valid/tb0792.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 133/200 /kaggle/working/inference/valid/tb0812.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 134/200 /kaggle/working/inference/valid/tb0824.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 135/200 /kaggle/working/inference/valid/tb0832.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 136/200 /kaggle/working/inference/valid/tb0842.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 137/200 /kaggle/working/inference/valid/tb0846.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 138/200 /kaggle/working/inference/valid/tb0849.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 139/200 /kaggle/working/inference/valid/tb0859.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 140/200 /kaggle/working/inference/valid/tb0860.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 141/200 /kaggle/working/inference/valid/tb0863.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 142/200 /kaggle/working/inference/valid/tb0870.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 143/200 /kaggle/working/inference/valid/tb0884.png: 640x640 1 ActiveTuberculosis, 48.5ms
# image 144/200 /kaggle/working/inference/valid/tb0898.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 145/200 /kaggle/working/inference/valid/tb0905.png: 640x640 1 ActiveTuberculosis, 48.5ms
# image 146/200 /kaggle/working/inference/valid/tb0912.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 147/200 /kaggle/working/inference/valid/tb0917.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 148/200 /kaggle/working/inference/valid/tb0918.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 149/200 /kaggle/working/inference/valid/tb0927.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 150/200 /kaggle/working/inference/valid/tb0934.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 151/200 /kaggle/working/inference/valid/tb0938.png: 640x640 3 ActiveTuberculosiss, 48.5ms
# image 152/200 /kaggle/working/inference/valid/tb0950.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 153/200 /kaggle/working/inference/valid/tb0951.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 154/200 /kaggle/working/inference/valid/tb0960.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 155/200 /kaggle/working/inference/valid/tb0963.png: 640x640 (no detections), 48.4ms
# image 156/200 /kaggle/working/inference/valid/tb0965.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 157/200 /kaggle/working/inference/valid/tb0980.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 158/200 /kaggle/working/inference/valid/tb0987.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 159/200 /kaggle/working/inference/valid/tb0995.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 160/200 /kaggle/working/inference/valid/tb1011.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 161/200 /kaggle/working/inference/valid/tb1012.png: 640x640 4 ActiveTuberculosiss, 48.4ms
# image 162/200 /kaggle/working/inference/valid/tb1019.png: 640x640 2 ActiveTuberculosiss, 48.8ms
# image 163/200 /kaggle/working/inference/valid/tb1021.png: 640x640 1 ActiveTuberculosis, 48.6ms
# image 164/200 /kaggle/working/inference/valid/tb1024.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 165/200 /kaggle/working/inference/valid/tb1028.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 166/200 /kaggle/working/inference/valid/tb1030.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 167/200 /kaggle/working/inference/valid/tb1031.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 168/200 /kaggle/working/inference/valid/tb1042.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 169/200 /kaggle/working/inference/valid/tb1052.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 170/200 /kaggle/working/inference/valid/tb1056.png: 640x640 3 ActiveTuberculosiss, 48.4ms
# image 171/200 /kaggle/working/inference/valid/tb1059.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 172/200 /kaggle/working/inference/valid/tb1060.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 173/200 /kaggle/working/inference/valid/tb1065.png: 640x640 1 ActiveTuberculosis, 2 ObsoletePulmonaryTuberculosiss, 48.4ms
# image 174/200 /kaggle/working/inference/valid/tb1067.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 175/200 /kaggle/working/inference/valid/tb1068.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 176/200 /kaggle/working/inference/valid/tb1080.png: 640x640 1 ActiveTuberculosis, 48.5ms
# image 177/200 /kaggle/working/inference/valid/tb1085.png: 640x640 1 ActiveTuberculosis, 48.4ms
# image 178/200 /kaggle/working/inference/valid/tb1090.png: 640x640 4 ActiveTuberculosiss, 48.4ms
# image 179/200 /kaggle/working/inference/valid/tb1093.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 180/200 /kaggle/working/inference/valid/tb1099.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 181/200 /kaggle/working/inference/valid/tb1113.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 182/200 /kaggle/working/inference/valid/tb1117.png: 640x640 5 ActiveTuberculosiss, 48.4ms
# image 183/200 /kaggle/working/inference/valid/tb1120.png: 640x640 1 ActiveTuberculosis, 48.5ms
# image 184/200 /kaggle/working/inference/valid/tb1124.png: 640x640 1 ActiveTuberculosis, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 185/200 /kaggle/working/inference/valid/tb1132.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 186/200 /kaggle/working/inference/valid/tb1133.png: 640x640 2 ActiveTuberculosiss, 48.5ms
# image 187/200 /kaggle/working/inference/valid/tb1136.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 188/200 /kaggle/working/inference/valid/tb1148.png: 640x640 3 ActiveTuberculosiss, 49.1ms
# image 189/200 /kaggle/working/inference/valid/tb1150.png: 640x640 4 ActiveTuberculosiss, 48.4ms
# image 190/200 /kaggle/working/inference/valid/tb1154.png: 640x640 2 ActiveTuberculosiss, 48.4ms
# image 191/200 /kaggle/working/inference/valid/tb1157.png: 640x640 1 ActiveTuberculosis, 48.5ms
# image 192/200 /kaggle/working/inference/valid/tb1160.png: 640x640 1 ActiveTuberculosis, 48.5ms
# image 193/200 /kaggle/working/inference/valid/tb1161.png: 640x640 2 ActiveTuberculosiss, 52.5ms
# image 194/200 /kaggle/working/inference/valid/tb1167.png: 640x640 2 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.5ms
# image 195/200 /kaggle/working/inference/valid/tb1168.png: 640x640 1 ActiveTuberculosis, 1 ObsoletePulmonaryTuberculosis, 48.5ms
# image 196/200 /kaggle/working/inference/valid/tb1173.png: 640x640 2 ActiveTuberculosiss, 50.0ms
# image 197/200 /kaggle/working/inference/valid/tb1177.png: 640x640 1 ActiveTuberculosis, 48.8ms
# image 198/200 /kaggle/working/inference/valid/tb1183.png: 640x640 3 ActiveTuberculosiss, 48.5ms
# image 199/200 /kaggle/working/inference/valid/tb1188.png: 640x640 4 ActiveTuberculosiss, 1 ObsoletePulmonaryTuberculosis, 48.4ms
# image 200/200 /kaggle/working/inference/valid/tb1192.png: 640x640 2 ActiveTuberculosiss, 49.5ms
# Speed: 0.5ms pre-process, 48.8ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7
# 189 labels saved to runs/detect/exp7/labels

# %%
# If you have run more than one times of detect.py, 
# the name of 'exp' in the path will be changed for storing the detecting results.
PRED_PATH = '/kaggle/working/yolov5/runs/detect/exp7/labels/'

# list our prediction files path
prediction_files = os.listdir(PRED_PATH)
print('Number of test images with detections: ', len(prediction_files))
# Out:
# Number of test images with detections:  184

# %%
Image.open('/kaggle/working/inference/valid/tb0950.png')

# %%
# %cd /kaggle/working/yolov5/runs/detect/exp5/
# !ls

# %%
Image.open('/kaggle/working/yolov5/runs/detect/exp/tb0950.png')

# %% [markdown]
# # End SMOTE

# %%
# !mkdir images/train 
# !mkdir images/val 
# !mkdir images/test 

# !mkdir annotations/train 
# !mkdir annotations/val 
# !mkdir annotations/test

# %%
len(os.listdir('/kaggle/working/Road_Sign_Dataset/images/train'))
#len(os.listdir('/kaggle/working/Road_Sign_Dataset/images/test'))
#len(os.listdir('/kaggle/working/Road_Sign_Dataset/images/val'))

# %%
#Utility function to move images 
def move_files_to_folder(list_of_files, destination_folder):
    for f in list_of_files:
        try:
            shutil.move(f, destination_folder)
        except:
            print(f)
            assert False

# Move the splits into their folders
move_files_to_folder(train_images, '/kaggle/working/Road_Sign_Dataset/images/train')
move_files_to_folder(val_images, '/kaggle/working/Road_Sign_Dataset/images/val/')
move_files_to_folder(test_images, '/kaggle/working/Road_Sign_Dataset/images/test/')
move_files_to_folder(train_annotations, '/kaggle/working/Road_Sign_Dataset/annotations/train/')
move_files_to_folder(val_annotations, '/kaggle/working/Road_Sign_Dataset/annotations/val/')
move_files_to_folder(test_annotations, '/kaggle/working/Road_Sign_Dataset/annotations/test/')
# !mv annotations labels
# %cd ../

# %%
# %cd /kaggle/working/Road_Sign_Dataset/
# !ls

# %%
len(os.listdir('/kaggle/working/Road_Sign_Dataset/labels/train/'))

# %%
# !wget -P data/ https://gist.githubusercontent.com/ayooshkathuria/bcf7e3c929cbad445439c506dba6198d/raw/f437350c0c17c4eaa1e8657a5cb836e65d8aa08a/road_sign_data.yaml

# %% [markdown]
# # INSTALL

# %%
# !pwd

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git  #&> /dev/null

# %%
# %cd yolov7

# %%
# !pip install -r requirements.txt &> /dev/null

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-e6e.pt

# %%
# !wget https://raw.githubusercontent.com/tkeldenich/How_to_use_YOLOv7_Tutorial/main/man_cafe.jpg

# %%
from PIL import Image
im = Image.open('man_cafe.jpg')
im

# %%
# !python detect.py --weights yolov7-e6e.pt --source ./man_cafe.jpg

# %%
im_res1 = Image.open('./runs/detect/exp/man_cafe.jpg')
im_res1

# %%
# !python detect.py --weights yolov7-e6e.pt --conf 0.60 --img-size 640 --source ./man_cafe.jpg

# %%
im_res2 = Image.open('./runs/detect/exp2/man_cafe.jpg')
im_res2

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-tiny.pt

# %%
# !python detect.py --weights yolov7-tiny.pt --conf 0.25 --img-size 640 --source ./man_cafe.jpg

# %%
im_res3 = Image.open('./runs/detect/exp3/man_cafe.jpg')
im_res3

# %%
# !cp -R /kaggle/working/Road_Sign_Dataset/data/road_sign_data.yaml /kaggle/working/Road_Sign_Dataset/yolov7/data/

# %%
# !pwd

# %%
# !pip install wandb

# %%
import wandb
wandb.login()

# %%
train: ../Road_Sign_Dataset/images/train/ 
val:  ../Road_Sign_Dataset/images/val/
test: ../Road_Sign_Dataset/images/test/

# number of classes
nc: 4

# class names
names: ["trafficlight","stop", "speedlimit","crosswalk"]

# %%
yamltext = """
train: /kaggle/working/Road_Sign_Dataset/images/train/ 
val:  /kaggle/working/Road_Sign_Dataset/images/val/
test: /kaggle/working/Road_Sign_Dataset/images/test/

# number of classes
nc: 2

# class names
names: ["ActiveTuberculosis","ObsoletePulmonaryTuberculosis"]

"""

with open("/kaggle/working/Road_Sign_Dataset/yolov7/data/road_sign_data.yaml", 'w') as file:
    file.write(yamltext)

#%cat /kaggle/working/data/data.yaml


# !cat /kaggle/working/Road_Sign_Dataset/yolov7/data/road_sign_data.yaml

# %%
# %cd /kaggle/working/Road_Sign_Dataset/yolov7

# %%
len(os.listdir('/kaggle/working/Road_Sign_Dataset/images/train/'))

# %% [markdown]
# # Train for 60 Epochs

# %%
class_weight_0=1.0
#class_weight_1=num_samples_class_0 / num_samples_class_1

class_weight_1= 972 / 269

print(class_weight_0)
print(class_weight_1)

# %%
# %cd yolov7

# %%
# !python train.py --img-size 512 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.custom.yaml --batch 8 --epochs 10 --data data/road_sign_data.yaml --weights yolov7-e6e.pt --workers 24 --cls_weights $class_weight_0 $class_weight_1 --name yolo_tbx31_1

# %% [markdown]
# # Train for 120 Epochs

# %%
# !python train.py --img-size 512 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.custom.yaml --batch 8 --epochs 130 --data data/road_sign_data.yaml --weights yolov7-e6e.pt --workers 24 --name yolo_det31Aug_130

# %%
# !pwd

# %%
# !python detect.py --source /kaggle/working/Road_Sign_Dataset/images/test/ --weights runs/train/yolo_tbx31_1/weights/best.pt --conf 0.05 --name yolo_tbx31_1

# %%
detections_dir = "runs/detect/yolo_tbx31_1/"
detection_images = [os.path.join(detections_dir, x) for x in os.listdir(detections_dir)]

random_detection_image = Image.open(random.choice(detection_images))
plt.imshow(np.array(random_detection_image))

# %% [markdown]
# # No weights

# %%
# !python train.py --img-size 512 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.custom.yaml --batch 8 --epochs 10 --data data/road_sign_data.yaml --weights '' --workers 24 --name yolo_det31Aug_noweights


#yolov7-e6e.pt

# %%
# !python test.py --weights runs/train/yolo_road_det3/weights/best.pt --data road_sign_data.yaml --task test --name yolo_det

# %% [markdown]
# # Inference for 130 Epochs

# %%
# !python detect.py --source /kaggle/working/Road_Sign_Dataset/images/test/ --weights runs/train/yolo_det31Aug_130/weights/best.pt --conf 0.05 --name yolo_road_det5

# %%
detections_dir = "runs/detect/yolo_road_det52/"
detection_images = [os.path.join(detections_dir, x) for x in os.listdir(detections_dir)]

random_detection_image = Image.open(random.choice(detection_images))
plt.imshow(np.array(random_detection_image))
